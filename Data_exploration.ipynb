# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("train.csv",parse_dates=[12,15])

# %%
df
# Out:
#         id departure city  discount    price  no of items location     class  \
# 0        1        Houston       0.2   16.448            2  Central  0.426336
# 1        2       Westland       0.0   29.700            5  Central  0.426336
# 2        3       Westland       0.0   14.730            3  Central  0.079218
# 3        4       Westland       0.0   43.920            3  Central  0.426336
# 4        5       Westland       0.0   66.580            2  Central  0.426336
# ...    ...            ...       ...      ...          ...      ...       ...
# 6695  6696     Burlington       0.0  542.940            3     East  0.426336
# 6696  6697       San Jose       0.2  276.784            2     West  0.426336
# 6697  6698     Burlington       0.0    2.040            1     East  0.426336
# 6698  6699  New York City       0.1  207.846            3     East  0.079218
# 6699  6700    Los Angeles       0.2  160.776            3     West  0.494446
#
# ...

# %%
df[df["delivery date"]!=df["placement date"]]
# Out:
#         id departure city  discount    price  no of items location   class  \
# 21      22  Mission Viejo      0.15  290.666            2     West   qexty
# 22      23        Detroit      0.00  229.940            2  Central  kariox
# 23      24        Detroit      0.00   10.560            2  Central  kariox
# 24      25  New York City      0.20    3.928            1     East  kariox
# 25      26      San Diego      0.00   36.440            4     West  kariox
# ...    ...            ...       ...      ...          ...      ...     ...
# 6483  6484        Phoenix      0.20  100.800            2     West  fynota
# 6484  6485        Phoenix      0.20   45.120            3     West  fynota
# 6485  6486        Phoenix      0.70  269.970            2     West  fynota
# 6486  6487        Phoenix      0.50   35.445            1     West   qexty
# 6489  6490         Nashua      0.00   21.120            4     East   qexty
#
# ...

# %%
df.columns
# Out:
# Index(['id', 'departure city', 'discount', 'price', 'no of items', 'location',
#        'class', 'segment', 'sub-class', 'delivery type', 'RID', 'profit',
#        'delivery date', 'address code', 'departure state', 'placement date'],
#       dtype='object')

# %%
df["segment"].unique()
# Out:
# array(['Consumer', 'Corporate', 'Home Office'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6700 entries, 0 to 6699
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               6700 non-null   int64
#  1   departure city   6700 non-null   object
#  2   discount         6700 non-null   float64
#  3   price            6700 non-null   float64
#  4   no of items      6700 non-null   int64
#  5   location         6700 non-null   object
#  6   class            6700 non-null   object
#  7   segment          6700 non-null   object
#  8   sub-class        6700 non-null   object
#  9   delivery type    6699 non-null   object
#  10  RID              6700 non-null   int64
#  11  profit           6700 non-null   float64
#  12  delivery date    6700 non-null   datetime64[ns]
#  13  address code     6700 non-null   int64
#  14  departure state  6700 non-null   object
#  15  placement date   6700 non-null   datetime64[ns]
# ...

# %%
df["delivery type"].unique()
# Out:
# array(['Standard Class', 'First Class', 'Second Class', nan, 'Same Day'],
#       dtype=object)

# %%
df["delivery date"].dtype
# Out:
# dtype('<M8[ns]')

# %%
df["Delay"].unique()
# Out:
# array([0], dtype=int64)

# %%
df["delivery date"].dt.day.unique()
# Out:
# array([1], dtype=int64)

# %%
df["Delay"]=df["placement date"]-df["delivery date"]

# %%
df["Delay"].unique()
# Out:
# array([  0., -31., -28., -30., -29.])

# %%
df["Delay"]=df["Delay"]/ np.timedelta64(1,"D")

# %%
df[df["Delay"]>0].count()
# Out:
# id                 828
# departure city     828
# discount           828
# price              828
# no of items        828
# location           828
# class              828
# segment            828
# sub-class          828
# delivery type      828
# RID                828
# profit             828
# delivery date      828
# address code       828
# departure state    828
# placement date     828
# Delay              828
# dtype: int64

# %%
df["Delay"].dtype
# Out:
# dtype('float64')

# %%
del df["placement date"]

# %%
df[df["profit"]==df["profit"].max()]
# Out:
#       discount     price  no of items location   class    segment sub-class  \
# 5895       0.0  17499.95            5  Central  fynota  Corporate  fastfood
#
#        delivery type    profit  Delay
# 5895  Standard Class  8399.976    0.0

# %%
sns.lineplot(df.price,df.profit)
# Out:
# C:\Users\B.THUSHAR\anaconda3\envs\tf2_object_detection\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='price', ylabel='profit'>

# %%
df["price/item"]=df["price"]/df["no of items"]

# %%
df.groupby("sub-class")["profit"].sum()
# Out:
# sub-class
# battery       10431.4839
# charger        -233.7867
# chocolates    26387.8677
# colddrinks    31711.9081
# fastfood      31966.0117
# headset       22611.5372
# hoodies       -9563.6884
# laptop        13981.4334
# lighting        649.5967
# pants         -2888.9299
# phone         22025.4419
# shorts         8959.9808
# sweets         6406.0608
# tablet         3801.6447
# television     4301.5003
# tshirts       18948.9264
# watch          5614.0209
# Name: profit, dtype: float64

# %%
del df["delivery date"]
del df["departure city"]
del df["departure state"]
del df["RID"]
del df["address code"]

# %%
del df["id"]

# %%
df["month"]=df["placement date"].dt.month
df["year"]=df["placement date"].dt.year

# %%
sns.barplot(df.month,df.profit)
# Out:
# C:\Users\B.THUSHAR\anaconda3\envs\tensorflow_env\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize=(15,5))
plt.plot(df["placement date"],df["profit"])
plt.xlabel("Datetime")
plt.ylabel("Profit")
plt.show()

# %%
pd.DataFrame(df.groupby(["year","month"])["profit"].sum())
# Out:
#                 profit
# year month
# 2018 1       2450.1907
#      2        862.3084
#      3        498.7299
#      4       3488.8352
#      5       2738.7096
#      6       4976.5244
#      7       -841.4826
#      8       5318.1050
#      9       8328.0994
#      10      3448.2573
#      11      9292.1269
#      12      8983.5699
# 2019 1      -3281.0070
#      2       2813.8508
#      3       9732.0978
#      4       4187.4962
#      5       4667.8690
#      6       3335.5572
#      7       3288.6483
#      8       5355.8084
#      9       8209.1627
#      10      2817.3660
#      11     12474.7884
#      12      8016.9659
# 2020 1       2824.8233
#      2       4996.2467
#      3       3625.2715
#      4       2957.8446
#      5       8627.4764
#      6       4499.5845
#      7       4464.6602
#      8       2328.3534
#      9       9360.4910
#      10     15763.3797
#      11      4376.0694
#      12     17902.7301
# 2021 1       2221.5009

# %%
sns.heatmap(df.corr(),annot=True)

# %%
df.head(2)
# Out:
#    discount   price  no of items location     class   segment  sub-class  \
# 0       0.2  16.448            2  Central  0.426336  Consumer   0.112887
# 1       0.0  29.700            5  Central  0.426336  Consumer   0.115891
#
#     delivery type   profit placement date  Delay  price/item  month  year
# 0  Standard Class   5.5512     2018-01-01    0.0       8.224      1  2018
# 1  Standard Class  13.3650     2018-01-01    0.0       5.940      1  2018

# %%
sns.heatmap(df[["price","discount","no of items","profit","month","year"]].corr(),annot=True)

# %%
sns.barplot(df.year,df.profit)
# Out:
# C:\Users\B.THUSHAR\anaconda3\envs\tensorflow_env\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
df["month"]=df["placement date"]
# Out:
#       discount    price  no of items location     class    segment  sub-class  \
# 0          0.2   16.448            2  Central  0.426336   Consumer   0.112887
# 1          0.0   29.700            5  Central  0.426336   Consumer   0.115891
# 2          0.0   14.730            3  Central  0.079218   Consumer   0.045922
# 3          0.0   43.920            3  Central  0.426336   Consumer   0.022046
# 4          0.0   66.580            2  Central  0.426336   Consumer   0.071659
# ...        ...      ...          ...      ...       ...        ...        ...
# 6695       0.0  542.940            3     East  0.426336   Consumer   0.053464
# 6696       0.2  276.784            2     West  0.426336  Corporate   0.115891
# 6697       0.0    2.040            1     East  0.426336   Consumer   0.028773
# 6698       0.1  207.846            3     East  0.079218  Corporate   0.097119
# 6699       0.2  160.776            3     West  0.494446   Consumer   0.162533
#
# ...

# %%
x_test=pd.read_csv("test.csv",parse_dates=[11,14])
del x_test["id"]

x_test["Delay"]=x_test["placement date"]-x_test["delivery date"]
x_test["Delay"]=x_test["Delay"]/ np.timedelta64(1,"D")

del x_test["delivery date"]
del x_test["placement date"]
del x_test["departure city"]
del x_test["departure state"]
del x_test["RID"]
del x_test["address code"]
x_test["price/item"]=x_test["price"]/x_test["no of items"]
x_test
# Out:
#       discount    price  no of items location   class      segment  \
# 0          0.0   24.200            5     West  kariox     Consumer
# 1          0.2  359.976            3     West  fynota     Consumer
# 2          0.0    3.520            2     East  kariox     Consumer
# 3          0.2   11.520            5  Central  kariox     Consumer
# 4          0.0  242.940            3     West  kariox  Home Office
# ...        ...      ...          ...      ...     ...          ...
# 3289       0.0   31.920            4     East  kariox     Consumer
# 3290       0.0   19.440            3     East  kariox     Consumer
# 3291       0.0  272.940            3     East  kariox     Consumer
# 3292       0.2  113.568            2     West   qexty     Consumer
# 3293       0.2    3.024            3     West  kariox     Consumer
#
#        sub-class   delivery type  Delay  price/item
# 0     television  Standard Class    0.0       4.840
# 1     colddrinks  Standard Class    0.0     119.992
# ...

# %%
x=df.groupby(["sub-class"]).sum().sort_values("profit",ascending=False)
x
# Out:
#                  id  discount        price  no of items      RID      profit  \
# sub-class
# fastfood     166398      7.60   89628.5920          166   232328  31966.0117
# colddrinks  1981020     89.40  224776.2800         2206  2938559  31711.9081
# chocolates  1690307     41.20  108150.0200         1904  2490810  26387.8677
# headset     3502032    378.80  130827.6420         3912  5152970  22611.5372
# phone       3075130     66.00   50805.3680         3478  4538001  22025.4419
# tshirts     1447159     73.30  233102.5960         1685  2112311  18948.9264
# laptop      1839990     41.20  155186.9480         2138  2675233  13981.4334
# battery     1013792     48.50   65174.0290         1081  1552222  10431.4839
# shorts      2186717     91.60   62790.0700         2466  3259656   8959.9808
# sweets       276073     25.40  146044.9290          322   406262   6406.0608
# watch        607454     14.40   13368.4440          670   881675   5614.0209
# ...

# %%
x.profit.sum()
# Out:
# 195111.00949999996

# %%
d={}
for i ,j  in zip(x.profit,x.profit.index):
    d[j]=i/195111

# %%
d
# Out:
# {'fastfood': 0.16383500520216696,
#  'colddrinks': 0.16253265115754612,
#  'chocolates': 0.13524541261128278,
#  'headset': 0.11589063251174975,
#  'phone': 0.11288672550496903,
#  'tshirts': 0.09711869858695824,
#  'laptop': 0.07165886802896806,
#  'battery': 0.05346435567446218,
#  'shorts': 0.04592247899913388,
#  'sweets': 0.03283290434675645,
#  'watch': 0.0287734720236173,
#  'television': 0.02204642639318131,
#  'tablet': 0.0194845226563341,
#  'lighting': 0.0033293699483883522,
#  'charger': -0.0011982240878269281,
#  'pants': -0.014806596757743028,
#  'hoodies': -0.049016654109711934}

# %%
df["sub-class"]=df["sub-class"].map(d)

# %%
df["class"]=df["class"].map(d)

# %%
df
# Out:
#       discount    price  no of items location     class    segment  sub-class  \
# 0          0.2   16.448            2  Central  0.426336   Consumer   0.112887
# 1          0.0   29.700            5  Central  0.426336   Consumer   0.115891
# 2          0.0   14.730            3  Central  0.079218   Consumer   0.045922
# 3          0.0   43.920            3  Central  0.426336   Consumer   0.022046
# 4          0.0   66.580            2  Central  0.426336   Consumer   0.071659
# ...        ...      ...          ...      ...       ...        ...        ...
# 6695       0.0  542.940            3     East  0.426336   Consumer   0.053464
# 6696       0.2  276.784            2     West  0.426336  Corporate   0.115891
# 6697       0.0    2.040            1     East  0.426336   Consumer   0.028773
# 6698       0.1  207.846            3     East  0.079218  Corporate   0.097119
# 6699       0.2  160.776            3     West  0.494446   Consumer   0.162533
#
# ...

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.barplot(df["class"],df.profit)
# Out:
# C:\Users\B.THUSHAR\anaconda3\envs\tf2_object_detection\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='class', ylabel='profit'>

# %%
df.groupby("class")["no of items"].sum()
# Out:
# class
# fynota     4598
# kariox    15256
# qexty      5596
# Name: no of items, dtype: int64

# %%
df.groupby("sub-class")["price"].max()
# Out:
# sub-class
# battery        2625.120
# charger        8187.650
# chocolates     3347.370
# colddrinks     4548.810
# fastfood      17499.950
# headset        9892.740
# hoodies        4297.644
# laptop         2934.330
# lighting         93.360
# pants          4404.900
# phone           733.950
# shorts         1336.440
# sweets        22638.480
# tablet          629.184
# television     1113.024
# tshirts        3785.292
# watch           604.656
# Name: price, dtype: float64

# %%
len(df["departure state"].unique())
# Out:
# 47

# %%
sns.countplot(df["Delay"])
# Out:
# C:\Users\B.THUSHAR\anaconda3\envs\tf2_object_detection\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Delay', ylabel='count'>

# %%
sns.heatmap(df.iloc[:,1:].corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.barplot(df["no of items"],df.profit)
# Out:
# C:\Users\B.THUSHAR\anaconda3\envs\tf2_object_detection\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='no of items', ylabel='profit'>

# %%
sns.lineplot(df["RID"],df.profit)
# Out:
# C:\Users\B.THUSHAR\anaconda3\envs\tf2_object_detection\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='RID', ylabel='profit'>

# %%
sns.lineplot(df["address code"],df.profit)
# Out:
# C:\Users\B.THUSHAR\anaconda3\envs\tf2_object_detection\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='address code', ylabel='profit'>

# %%
del df["placement date"]

# %%
sns.barplot(df.segment,df.profit)
# Out:
# C:\Users\B.THUSHAR\anaconda3\envs\tf2_object_detection\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='segment', ylabel='profit'>

# %%
d={"Home Office":3,"Corporate":2,"Consumer":1}
df["segment"]=df["segment"].map(d)

# %%
df.segment.unique()
# Out:
# array([1, 2, 3], dtype=int64)

# %%
df
# Out:
#         id departure city  discount    price  no of items location   class  \
# 0        1        Houston       0.2   16.448            2  Central  kariox
# 1        2       Westland       0.0   29.700            5  Central  kariox
# 2        3       Westland       0.0   14.730            3  Central   qexty
# 3        4       Westland       0.0   43.920            3  Central  kariox
# 4        5       Westland       0.0   66.580            2  Central  kariox
# ...    ...            ...       ...      ...          ...      ...     ...
# 6695  6696     Burlington       0.0  542.940            3     East  kariox
# 6696  6697       San Jose       0.2  276.784            2     West  kariox
# 6697  6698     Burlington       0.0    2.040            1     East  kariox
# 6698  6699  New York City       0.1  207.846            3     East   qexty
# 6699  6700    Los Angeles       0.2  160.776            3     West  fynota
#
# ...

# %%
sns.barplot(df.location,df.profit)
# Out:
# C:\Users\B.THUSHAR\anaconda3\envs\tf2_object_detection\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='location', ylabel='profit'>

# %%
d={"Central":1,"East":2,"West":3,"South":4}
df["location"]=df["location"].map(d)

# %%
df
# Out:
#         id departure city  discount    price  no of items  location   class  \
# 0        1        Houston       0.2   16.448            2         1  kariox
# 1        2       Westland       0.0   29.700            5         1  kariox
# 2        3       Westland       0.0   14.730            3         1   qexty
# 3        4       Westland       0.0   43.920            3         1  kariox
# 4        5       Westland       0.0   66.580            2         1  kariox
# ...    ...            ...       ...      ...          ...       ...     ...
# 6695  6696     Burlington       0.0  542.940            3         2  kariox
# 6696  6697       San Jose       0.2  276.784            2         3  kariox
# 6697  6698     Burlington       0.0    2.040            1         2  kariox
# 6698  6699  New York City       0.1  207.846            3         2   qexty
# 6699  6700    Los Angeles       0.2  160.776            3         3  fynota
#
# ...

# %%
sns.regplot(df.profit,df.price)
# Out:
# C:\Users\B.THUSHAR\anaconda3\envs\tf2_object_detection\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='profit', ylabel='price'>

# %%
df.price.sum()
# Out:
# 1570642.6441

# %%
df.profit.sum()
# Out:
# 195111.0095

# %%
len(df.RID.unique())
# Out:
# 6700

# %%
del df["RID"]

# %%
sns.barplot(df.discount,df.profit)
# Out:
# C:\Users\B.THUSHAR\anaconda3\envs\tf2_object_detection\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='discount', ylabel='profit'>

# %%
sns.barplot(df["class"],df.profit)
# Out:
# C:\Users\B.THUSHAR\anaconda3\envs\tf2_object_detection\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='class', ylabel='profit'>

# %%
d={"kariox":2,"qexty":1,"fynota":3}
df["class"]=df["class"].map(d)

# %%
df
# Out:
#         id departure city  discount    price  no of items  location  class  \
# 0        1        Houston       0.2   16.448            2         1      2
# 1        2       Westland       0.0   29.700            5         1      2
# 2        3       Westland       0.0   14.730            3         1      1
# 3        4       Westland       0.0   43.920            3         1      2
# 4        5       Westland       0.0   66.580            2         1      2
# ...    ...            ...       ...      ...          ...       ...    ...
# 6695  6696     Burlington       0.0  542.940            3         2      2
# 6696  6697       San Jose       0.2  276.784            2         3      2
# 6697  6698     Burlington       0.0    2.040            1         2      2
# 6698  6699  New York City       0.1  207.846            3         2      1
# 6699  6700    Los Angeles       0.2  160.776            3         3      3
#
#       segment   sub-class   delivery type    profit  address code  \
# ...

# %%
sns.barplot(df["delivery type"],df.profit)
# Out:
# C:\Users\B.THUSHAR\anaconda3\envs\tf2_object_detection\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='delivery type', ylabel='profit'>

# %%
sns.barplot(df["delivery type"],df.profit)
# Out:
# C:\Users\B.THUSHAR\anaconda3\envs\tf2_object_detection\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='delivery type', ylabel='profit'>

# %%
df["departure state"].groupby(df["departure city"])

# %%
np.percentile(df["profit"],0.5)
# Out:
# -475.423876

# %%
df[df["profit"]>0].count()
# Out:
# id                 5403
# departure city     5403
# discount           5403
# price              5403
# no of items        5403
# location           5403
# class              5403
# segment            5403
# sub-class          5403
# delivery type      5402
# profit             5403
# address code       5403
# departure state    5403
# Delay              5403
# dtype: int64

# %%
df.describe()
# Out:
#                 id     discount         price  no of items       profit  \
# count  6700.000000  6700.000000   6700.000000  6700.000000  6700.000000
# mean   3350.500000     0.155876    234.424275     3.798507    29.121046
# std    1934.267734     0.205922    641.440815     2.225327   230.712951
# min       1.000000     0.000000      0.836000     1.000000 -6599.978000
# 25%    1675.750000     0.000000     17.340000     2.000000     1.713750
# 50%    3350.500000     0.200000     54.960000     3.000000     8.803200
# 75%    5025.250000     0.200000    212.940000     5.000000    30.023400
# max    6700.000000     0.800000  22638.480000    14.000000  8399.976000
#
#        address code        Delay
# count   6700.000000  6700.000000
# mean   54719.073284    -3.775970
# std    32092.421012    10.058337
# min     1040.000000   -31.000000
# 25%    22204.000000     0.000000
# 50%    55113.000000     0.000000
# 75%    90004.000000     0.000000
# max    99301.000000     0.000000

# %%
df
# Out:
#         id departure city  discount    price  no of items  location  class  \
# 0        1        Houston       0.2   16.448            2         1      2
# 1        2       Westland       0.0   29.700            5         1      2
# 2        3       Westland       0.0   14.730            3         1      1
# 3        4       Westland       0.0   43.920            3         1      2
# 4        5       Westland       0.0   66.580            2         1      2
# ...    ...            ...       ...      ...          ...       ...    ...
# 6695  6696     Burlington       0.0  542.940            3         2      2
# 6696  6697       San Jose       0.2  276.784            2         3      2
# 6697  6698     Burlington       0.0    2.040            1         2      2
# 6698  6699  New York City       0.1  207.846            3         2      1
# 6699  6700    Los Angeles       0.2  160.776            3         3      3
#
#       segment   sub-class   delivery type    profit  address code  \
# ...

# %%
df["delivery type"]=df["delivery type"].fillna("Same Day")

# %%
df.isnull().sum()
# Out:
# id                 0
# departure city     0
# discount           0
# price              0
# no of items        0
# location           0
# class              0
# segment            0
# sub-class          0
# delivery type      0
# profit             0
# address code       0
# departure state    0
# Delay              0
# dtype: int64

# %%
del df["address code"]
del df["departure city"]
del df["departure state"]

# %%
del df["id"]

# %%
x=df.groupby("sub-class")["profit"].sum().sort_values()
x.index
# Out:
# Index(['hoodies', 'pants', 'charger', 'lighting', 'tablet', 'television',
#        'watch', 'sweets', 'shorts', 'battery', 'laptop', 'tshirts', 'phone',
#        'headset', 'chocolates', 'colddrinks', 'fastfood'],
#       dtype='object', name='sub-class')

# %%
d={}
n=1
for i in df.groupby("sub-class")["profit"].sum().sort_values().index:
    d[i]=n
    n+=1

# %%
d
# Out:
# {'hoodies': 1,
#  'pants': 2,
#  'charger': 3,
#  'lighting': 4,
#  'tablet': 5,
#  'television': 6,
#  'watch': 7,
#  'sweets': 8,
#  'shorts': 9,
#  'battery': 10,
#  'laptop': 11,
#  'tshirts': 12,
#  'phone': 13,
#  'headset': 14,
#  'chocolates': 15,
#  'colddrinks': 16,
#  'fastfood': 17}

# %%
df["sub-class"]=df["sub-class"].map(d)

# %%
df
# Out:
#       discount    price  no of items  location  class  segment  sub-class  \
# 0          0.2   16.448            2         1      2        1         13
# 1          0.0   29.700            5         1      2        1         14
# 2          0.0   14.730            3         1      1        1          9
# 3          0.0   43.920            3         1      2        1          6
# 4          0.0   66.580            2         1      2        1         11
# ...        ...      ...          ...       ...    ...      ...        ...
# 6695       0.0  542.940            3         2      2        1         10
# 6696       0.2  276.784            2         3      2        2         14
# 6697       0.0    2.040            1         2      2        1          7
# 6698       0.1  207.846            3         2      1        2         12
# 6699       0.2  160.776            3         3      3        1         16
#
#        delivery type    profit  Delay
# 0     Standard Class    5.5512    0.0
# ...

# %%
pd.DataFrame(df.groupby("sub-class")["profit"].max())
# Out:
#                profit
# sub-class
# battery      751.7601
# charger      327.5060
# chocolates   762.1845
# colddrinks  1228.1787
# fastfood    8399.9760
# headset     4946.3700
# hoodies      629.0100
# laptop       792.2691
# lighting      21.8880
# pants       1013.1270
# phone        352.2960
# shorts       387.5676
# sweets      2799.9840
# tablet       240.8595
# television   112.5740
# tshirts      770.3520
# watch        204.0714

# %%
sns.pairplot(df)

# %%
df
# Out:
#         id departure city  discount    price  no of items location   class  \
# 0        1        Houston       0.2   16.448            2  Central  kariox
# 1        2       Westland       0.0   29.700            5  Central  kariox
# 2        3       Westland       0.0   14.730            3  Central   qexty
# 3        4       Westland       0.0   43.920            3  Central  kariox
# 4        5       Westland       0.0   66.580            2  Central  kariox
# ...    ...            ...       ...      ...          ...      ...     ...
# 6695  6696     Burlington       0.0  542.940            3     East  kariox
# 6696  6697       San Jose       0.2  276.784            2     West  kariox
# 6697  6698     Burlington       0.0    2.040            1     East  kariox
# 6698  6699  New York City       0.1  207.846            3     East   qexty
# 6699  6700    Los Angeles       0.2  160.776            3     West  fynota
#
# ...
